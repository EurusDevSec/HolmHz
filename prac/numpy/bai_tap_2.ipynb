# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
my_array = np.zeros((20,20))

# %%
my_array[0:5, 0:5] = 255
my_array[15: 20 , 15:20] = 100
print(np.mean(my_array))
# Out:
# 22.1875

# %%
plt.imshow(my_array)
plt.show()
